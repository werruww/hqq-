# %%
# !pip install pip --upgrade && pip install transformers --upgrade

# %%
#Load model
import transformers, torch

#GPU runtime
device        = 'cuda'
compute_dtype = torch.float16

##CPU runtime
#device        = 'cpu'
#compute_dtype = torch.float32

cache_path    = ''
model_id      = "mobiuslabsgmbh/aanaphi2-v0.1"
model         = transformers.AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=compute_dtype,
                                                                  cache_dir=cache_path,
                                                                  device_map=device)
tokenizer     = transformers.AutoTokenizer.from_pretrained(model_id, cache_dir=cache_path)

#Set Prompt format
instruction_template = "### Human: "
response_template    = "### Assistant: "
def prompt_format(prompt):
    out = instruction_template + prompt + '\n' + response_template
    return out
model.eval();

@torch.no_grad()
def generate(prompt, max_length=1024):
    prompt_chat = prompt_format(prompt)
    inputs      = tokenizer(prompt_chat, return_tensors="pt", return_attention_mask=True).to(device)
    outputs     = model.generate(**inputs, max_length=max_length, eos_token_id= tokenizer.eos_token_id)
    text        = tokenizer.batch_decode(outputs[:,:-1])[0]
    return text

#Generate
print(generate('If A+B=C and B=C, what would be the value of A?'))

# %% [markdown]
# https://huggingface.co/mobiuslabsgmbh/aanaphi2-v0.1

# %%
#Load model
import transformers, torch

#GPU runtime
device        = 'cpu'
compute_dtype = torch.float32

##CPU runtime
#device        = 'cpu'
#compute_dtype = torch.float32

cache_path    = ''
model_id      = "mobiuslabsgmbh/aanaphi2-v0.1"
model         = transformers.AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=compute_dtype,
                                                                  cache_dir=cache_path,
                                                                  device_map=device)
tokenizer     = transformers.AutoTokenizer.from_pretrained(model_id, cache_dir=cache_path)

#Set Prompt format
instruction_template = "### Human: "
response_template    = "### Assistant: "
def prompt_format(prompt):
    out = instruction_template + prompt + '\n' + response_template
    return out
model.eval();

@torch.no_grad()
def generate(prompt, max_length=128):
    prompt_chat = prompt_format(prompt)
    inputs      = tokenizer(prompt_chat, return_tensors="pt", return_attention_mask=True).to(device)
    outputs     = model.generate(**inputs, max_length=max_length, eos_token_id= tokenizer.eos_token_id)
    text        = tokenizer.batch_decode(outputs[:,:-1])[0]
    return text

#Generate
print(generate('If A+B=C and B=C, what would be the value of A?'))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ### Human: If A+B=C and B=C, what would be the value of A?
# ### Assistant:
#
# If A + B = C and B = C, then substituting B = C into the first equation, we get:
#
# A + C = C
#
# To find the value of A, we can subtract C from both sides of the equation:
#
# A = C - C
#
# A = 0
#
# So, if A + B = C and B = C, then A = 0.

# %% [markdown]
# https://github.com/mobiusml/hqq/issues/143

# %%
# pip install https://vllm-wheels.s3.us-west-2.amazonaws.com/b63ba848323efd88207b12d7582501d525503b8a/vllm-1.0.0.dev-cp38-abi3-manylinux1_x86_64.whl;
# pip install hqq;

# %%
# !pip install hqq;
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 47.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.9 MB/s eta 0:00:00
# ...

# %%
# pip install https://vllm-wheels.s3.us-west-2.amazonaws.com/b63ba848323efd88207b12d7582501d525503b8a/vllm-1.0.0.dev-cp38-abi3-manylinux1_x86_64.whl;
# pip install hqq;
####################################################################################
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig

model_path = "meta-llama/Meta-Llama-3-8B-Instruct"
quant_model = "quant_model"

quant_config = HqqConfig(nbits=4, group_size=64, axis=1)

model = AutoModelForCausalLM.from_pretrained(model_path,
                                            torch_dtype=torch.float16,
                                            cache_dir='.',
                                            device_map="cuda:0",
                                            quantization_config=quant_config,
                                            low_cpu_mem_usage=True)

tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)

model.save_pretrained(quant_model)
tokenizer.save_pretrained(quant_model)
#Close this

####################################################################################
from vllm import LLM
from vllm import SamplingParams
import random

llm = LLM(model="quant_model", max_model_len=4096)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig

model_path = "openai-community/gpt2"
quant_model = "quant_model"

quant_config = HqqConfig(nbits=4, group_size=64, axis=1)

model = AutoModelForCausalLM.from_pretrained(model_path,
                                            torch_dtype=torch.float16,
                                            cache_dir='.',
                                            device_map="auto",
                                            quantization_config=quant_config,
                                            low_cpu_mem_usage=True)

tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)

model.save_pretrained(quant_model)
tokenizer.save_pretrained(quant_model)
#Close this
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# ...

# %%
# !pip install vllm
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.2/264.2 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 93.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 30.7 MB/s eta 0:00:00
# ...

# %%
####################################################################################
from vllm import LLM
from vllm import SamplingParams
import random

llm = LLM(model="quant_model", max_model_len=50)
# Out:
# INFO 02-04 04:20:33 __init__.py:183] Automatically detected platform cuda.
# INFO 02-04 04:20:46 config.py:526] This model supports multiple tasks: {'embed', 'score', 'reward', 'classify', 'generate'}. Defaulting to 'generate'.
# WARNING 02-04 04:20:47 config.py:605] hqq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-0b251e261c62> in <cell line: 0>()
#       4 import random
#       5
# ----> 6 llm = LLM(model="quant_model", max_model_len=50)
#
# /usr/local/lib/python3.11/dist-packages/vllm/utils.py in inner(*args, **kwargs)
#    1037                     )
#    1038
# -> 1039             return fn(*args, **kwargs)
#    1040
#    1041         return inner  # type: ignore
#
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/v6-Finch-1B6-HF", trust_remote_code=True, torch_dtype=torch.float16).to(0)
tokenizer = AutoTokenizer.from_pretrained("RWKV/v6-Finch-1B6-HF", trust_remote_code=True)

text = "Write an essay about large language models."
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt").to(0)
attention_mask = inputs["attention_mask"]
output = model.generate(inputs["input_ids"], attention_mask=attention_mask, max_new_tokens=128, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))

# %%
# !pip install auto-gptq --upgrade
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 45.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 73.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from auto_gptq import AutoGPTQForCausalLM

model_path = "openai-community/gpt2"
quant_model = "quant_model"

# Use AutoGPTQForCausalLM instead of AutoModelForCausalLM
model = AutoGPTQForCausalLM.from_pretrained(model_path,
                                            torch_dtype=torch.float16,
                                            cache_dir='.',
                                            device_map="auto",
                                            low_cpu_mem_usage=True)

tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)

# Perform GPTQ quantization
model.quantize_model(4)  # Quantize to 4 bits

model.save_pretrained(quant_model)
tokenizer.save_pretrained(quant_model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d4f95cb53caa> in <cell line: 0>()
#       1 import torch
#       2 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 3 from auto_gptq import AutoGPTQForCausalLM
#       4
#       5 model_path = "openai-community/gpt2"
#
# ModuleNotFoundError: No module named 'auto_gptq'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig

model_path = "openai-community/gpt2"
quant_model = "quant_model"

quant_config = HqqConfig(nbits=4, group_size=64, axis=1)

# Set device_map to "cpu"
model = AutoModelForCausalLM.from_pretrained(model_path,
                                            torch_dtype=torch.float16,
                                            cache_dir='.',
                                            device_map="cpu", # Changed to cpu
                                            quantization_config=quant_config,
                                            low_cpu_mem_usage=True)

tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)

model.save_pretrained(quant_model)
tokenizer.save_pretrained(quant_model)

# %% [markdown]
# https://huggingface.co/RWKV/v6-Finch-1B6-HF

# %%
# !pip install triton==2.2.0

# %%
# !pip install -U git+https://github.com/sustcsonglin/flash-linear-attention

# %% [markdown]
# https://github.com/fla-org/flash-linear-attention

# %% [markdown]
# ayhgشغال

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/v6-Finch-1B6-HF", trust_remote_code=True, torch_dtype=torch.float16).to(0)
tokenizer = AutoTokenizer.from_pretrained("RWKV/v6-Finch-1B6-HF", trust_remote_code=True)

text = "Write an essay about large language models."
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt").to(0)
attention_mask = inputs["attention_mask"]
output = model.generate(inputs["input_ids"], attention_mask=attention_mask, max_new_tokens=128, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/610 [00:00<?, ?B/s]
# configuration_rwkv6.py:   0%|          | 0.00/5.08k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/v6-Finch-1B6-HF:
# - configuration_rwkv6.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %% [markdown]
# https://huggingface.co/RWKV/v6-Finch-1B6-HF

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/v6-Finch-1B6-HF", trust_remote_code=True, torch_dtype=torch.float16).to(0)
tokenizer = AutoTokenizer.from_pretrained("RWKV/v6-Finch-1B6-HF", trust_remote_code=True)

text = "Write an essay about large language models."
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt").to(0)
attention_mask = inputs["attention_mask"]
output = model.generate(inputs["input_ids"], attention_mask=attention_mask, max_new_tokens=128, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))

# %%
from faster_whisper import WhisperModel

model = WhisperModel("faster-whisper-large-v3-turbo")

segments, info = model.transcribe("audio.mp3")
for segment in segments:
    print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-71544cfe6311> in <cell line: 0>()
# ----> 1 from faster_whisper import WhisperModel
#       2
#       3 model = WhisperModel("faster-whisper-large-v3-turbo")
#       4
#       5 segments, info = model.transcribe("audio.mp3")
#
# ModuleNotFoundError: No module named 'faster_whisper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install hqq==0.1.8
# !pip install bitblas
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 73.3 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/IST-DASLab/marlin.git #to use the marlin backend
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#   Cloning https://github.com/IST-DASLab/marlin.git to /tmp/pip-req-build-4w1j0lsf
#   Running command git clone --filter=blob:none --quiet https://github.com/IST-DASLab/marlin.git /tmp/pip-req-build-4w1j0lsf
#   Resolved https://github.com/IST-DASLab/marlin.git to commit 1f25790bdd49fba53106164a24666dade68d7c90
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for marlin
#   Running setup.py clean for marlin
# ...

# %%
import torch
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

#Load the model
###################################################
model_id = 'mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq'
model     = HQQModelForCausalLM.from_quantized(model_id, cache_dir='.', compute_dtype=torch.float16, adapter='adapter_v0.1.lora')
tokenizer = AutoTokenizer.from_pretrained(model_id)

patch_linearlayers(model, patch_add_quant_config,
                          BaseQuantizeConfig(nbits=2, group_size=64, quant_scale=False, quant_zero=False, axis=1))

model.eval();
cleanup()
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# ...

# %%
import torch
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

#Load the model
###################################################
model_id = 'mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq'
model     = HQQModelForCausalLM.from_quantized(model_id, cache_dir='.')
tokenizer = AutoTokenizer.from_pretrained(model_id)

patch_linearlayers(model, patch_add_quant_config,
                          BaseQuantizeConfig(nbits=2, group_size=64, quant_scale=False, quant_zero=False, axis=1))

model.eval();
cleanup()
# Out:
# ...
#   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-cdfe9eb0cb94> in <cell line: 0>()
#       8 ###################################################
#       9 model_id = 'mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq'
# ---> 10 model     = HQQModelForCausalLM.from_quantized(model_id, cache_dir='.')
#      11 tokenizer = AutoTokenizer.from_pretrained(model_id)
#      12
#
# /usr/local/lib/python3.11/dist-packages/hqq/engine/base.py in from_quantized(cls, save_dir_or_hub, compute_dtype, device, cache_dir, adapter)
#      85         cls._check_arch_support(arch_key)
#      86
# ---> 87         model = cls._get_hqq_class(arch_key).from_quantized(
#      88             save_dir,
#      89             compute_dtype=compute_dtype,
#
# ...

# %%
# !pip list
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.2.1
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.11
# aiohttp-cors                       0.7.0
# aiosignal                          1.3.2
# airportsdata                       20241001
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# ...

# %%
#Use optimized inference kernels
###################################################
HQQLinear.set_backend(HQQBackend.PYTORCH)
#prepare_for_inference(model) #default backend
prepare_for_inference(model, backend="bitblas", allow_merge=False) #It takes a while...

# %%
#Generate
###################################################
#For longer context, make sure to allocate enough cache via the cache_size= parameter
#gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

gen.generate("Write an essay about large language models", print_tokens=True)
gen.generate("Tell me a funny joke!", print_tokens=True)
gen.generate("How to make a yummy chocolate cake?", print_tokens=True)

# %%
# !pip show hqq_aten
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Name: hqq_aten
# Version: 0.0.0
# Summary:
# Home-page:
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg
# Requires:
# Required-by:

# %%
# !pip install hqq --upgrade
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#   Using cached hqq-0.2.2-py3-none-any.whl
# ...
#   Attempting uninstall: hqq
#     Found existing installation: hqq 0.1.8
#     Uninstalling hqq-0.1.8:
#       Successfully uninstalled hqq-0.1.8
# ...

# %%
#!pip install hqq==0.1.8
# !pip install bitblas
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
# !pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 60.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 95.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 73.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.4/883.4 kB 59.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 MB 4.5 MB/s eta 0:00:00
# ...

# %%
import torch
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

# Load the model
###################################################
model_id = 'mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq'
model     = HQQModelForCausalLM.from_quantized(model_id, cache_dir='.', compute_dtype=torch.float16, adapter='adapter_v0.1.lora')
tokenizer = AutoTokenizer.from_pretrained(model_id)

patch_linearlayers(model, patch_add_quant_config,
                          BaseQuantizeConfig(nbits=2, group_size=64, quant_scale=False, quant_zero=False, axis=1))

model.eval();
cleanup()

# Use optimized inference kernels
###################################################
HQQLinear.set_backend(HQQBackend.PYTORCH)
# prepare_for_inference(model) #default backend
prepare_for_inference(model, backend="bitblas", allow_merge=False) #It takes a while...

# Generate
###################################################
# For longer context, make sure to allocate enough cache via the cache_size= parameter
# gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=100, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

gen.generate("Write an essay about large language models", print_tokens=True)
gen.generate("Tell me a funny joke!", print_tokens=True)
gen.generate("How to make a yummy chocolate cake?", print_tokens=True)
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# ...

# %%
# !pip show hqq
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Name: hqq
# Version: 0.1.8
# Summary: Half-Quadratic Quantization (HQQ)
# Home-page: https://github.com/mobiusml/hqq/
# Author: Dr. Hicham Badri
# Author-email: hicham@mobiuslabs.com
# License: Apache 2
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: accelerate, bitblas, einops, huggingface-hub, numpy, termcolor, tqdm, transformers
# Required-by:

# %%
# !pip install hqq==0.2
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for hqq: filename=hqq-0.2.0-py3-none-any.whl size=63458 sha256=cb76a95b06f58f9fdb68ea780e6c51d9801984ce3a94ef22eec31be825de079f
#   Stored in directory: /root/.cache/pip/wheels/da/f1/ee/59dd5db559155bea59a66594eed1e7c1c8e038751f5c7cdc1c
# Successfully built hqq
# ...
#   Attempting uninstall: hqq
#     Found existing installation: hqq 0.1.8
#     Uninstalling hqq-0.1.8:
#       Successfully uninstalled hqq-0.1.8
# ...

# %%
# !pip install einops

# %%
# pip install transformers==4.47.0;
# pip install hqq --upgrade;
##################################################################
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig

model_path = "meta-llama/Meta-Llama-3-8B-Instruct"
quant_model = "quant_model"

quant_config = HqqConfig(nbits=4, group_size=64, axis=1)

model = AutoModelForCausalLM.from_pretrained(model_path,
                                            torch_dtype=torch.float16,
                                            cache_dir='.',
                                            device_map="cuda:0",
                                            quantization_config=quant_config,
                                            low_cpu_mem_usage=True)

tokenizer = AutoTokenizer.from_pretrained(model_path)

model.save_pretrained(quant_model)
tokenizer.save_pretrained(quant_model)

# %%
# !pip install transformers==4.47.0;
# !pip install hqq --upgrade;
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 50.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.2
#     Uninstalling transformers-4.48.2:
#       Successfully uninstalled transformers-4.48.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.7.1 requires torch==2.5.1, but you have torch 2.4.0+cu124 which is incompatible.
# ...

# %%
# pip install transformers==4.47.0;
# pip install hqq --upgrade;
##################################################################
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig

model_path = "openai-community/gpt2"
quant_model = "quant_model"

quant_config = HqqConfig(nbits=4, group_size=64, axis=1)

model = AutoModelForCausalLM.from_pretrained(model_path,
                                            torch_dtype=torch.float16,
                                            cache_dir='.',
                                            device_map="cuda:0",
                                            quantization_config=quant_config,
                                            low_cpu_mem_usage=True)

tokenizer = AutoTokenizer.from_pretrained(model_path)

model.save_pretrained(quant_model)
tokenizer.save_pretrained(quant_model)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ('quant_model/tokenizer_config.json',
#  'quant_model/special_tokens_map.json',
#  'quant_model/vocab.json',
#  'quant_model/merges.txt',
#  'quant_model/added_tokens.json',
#  'quant_model/tokenizer.json')

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("quant_model")
tokenizer = AutoTokenizer.from_pretrained("quant_model")
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.

# %%
inputs = tokenizer("ما هي عاصمة فرنسا؟", return_tensors="pt")

# %%
outputs = model.generate(**inputs)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(text)  # سيتم طباعة "باريس"
# Out:
# ما هي عاصمة فرنسا؟ في عنها عليه عليه ع

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("quant_model")
tokenizer = AutoTokenizer.from_pretrained("quant_model")
inputs = tokenizer("ما هي عاصمة فرنسا؟", return_tensors="pt")
outputs = model.generate(**inputs)
text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(text)  # سيتم طباعة "باريس"
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ما هي عاصمة فرنسا؟ في عنها عليه عليه ع

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq")
tokenizer = AutoTokenizer.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq")
inputs = tokenizer("ما هي عاصمة فرنسا؟", return_tensors="pt")
outputs = model.generate(**inputs)
text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(text)  # سيتم طباعة "باريس"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-64b4e2c609ad> in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
#       2
# ----> 3 model = AutoModelForCausalLM.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq")
#       4 tokenizer = AutoTokenizer.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq")
#       5 inputs = tokenizer("ما هي عاصمة فرنسا؟", return_tensors="pt")
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566             )
# --> 567         raise ValueError(
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer # or from transformers import AutoModel, AutoTokenizer

model = AutoModelForSeq2SeqLM.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq") # or model = AutoModel.from_pretrained(...)
tokenizer = AutoTokenizer.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq")
inputs = tokenizer("ما هي عاصمة فرنسا؟", return_tensors="pt")
outputs = model.generate(**inputs)
text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(text)  # سيتم طباعة "باريس"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-3507742506fc> in <cell line: 0>()
#       1 from transformers import AutoModelForSeq2SeqLM, AutoTokenizer # or from transformers import AutoModel, AutoTokenizer
#       2
# ----> 3 model = AutoModelForSeq2SeqLM.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq") # or model = AutoModel.from_pretrained(...)
#       4 tokenizer = AutoTokenizer.from_pretrained("/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq")
#       5 inputs = tokenizer("ما هي عاصمة فرنسا؟", return_tensors="pt")
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
# ...

# %%
#Load model
import transformers, torch

#GPU runtime
device        = 'cuda'
compute_dtype = torch.float16

##CPU runtime
#device        = 'cpu'
#compute_dtype = torch.float32

cache_path    = ''
model_id      = "mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq"
model         = transformers.AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=compute_dtype,
                                                                  cache_dir=cache_path,
                                                                  device_map=device)
tokenizer     = transformers.AutoTokenizer.from_pretrained(model_id, cache_dir=cache_path)

#Set Prompt format
instruction_template = "### Human: "
response_template    = "### Assistant: "
def prompt_format(prompt):
    out = instruction_template + prompt + '\n' + response_template
    return out
model.eval();

@torch.no_grad()
def generate(prompt, max_length=1024):
    prompt_chat = prompt_format(prompt)
    inputs      = tokenizer(prompt_chat, return_tensors="pt", return_attention_mask=True).to(device)
    outputs     = model.generate(**inputs, max_length=max_length, eos_token_id= tokenizer.eos_token_id)
    text        = tokenizer.batch_decode(outputs[:,:-1])[0]
    return text

#Generate
print(generate('If A+B=C and B=C, what would be the value of A?'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-df1e79b803f8> in <cell line: 0>()
#      12 cache_path    = ''
#      13 model_id      = "mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq"
# ---> 14 model         = transformers.AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=compute_dtype,
#      15                                                                   cache_dir=cache_path,
#      16                                                                   device_map=device)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562         elif type(config) in cls._model_mapping.keys():
#     563             model_class = _get_model_class(config, cls._model_mapping)
# --> 564             return model_class.from_pretrained(
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq", trust_remote_code=True, torch_dtype=torch.float16).to(0)
tokenizer = AutoTokenizer.from_pretrained("mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq", trust_remote_code=True)

text = "Write an essay about large language models."
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt").to(0)
attention_mask = inputs["attention_mask"]
output = model.generate(inputs["input_ids"], attention_mask=attention_mask, max_new_tokens=128, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-bd87bbc4788d> in <cell line: 0>()
#      21
#      22
# ---> 23 model = AutoModelForCausalLM.from_pretrained("mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq", trust_remote_code=True, torch_dtype=torch.float16).to(0)
# ...

# %%
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
import torch

# اسم النموذج
model_id = "mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq"

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحميل النموذج في وضع الاستدلال
model = HQQModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto"  # تخصيص تلقائي للجهاز (CUDA)
)

# تأكد أن النموذج يعمل على CUDA
model.to("cuda")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-2a02d41aa305> in <cell line: 0>()
#       9
#      10 # تحميل النموذج في وضع الاستدلال
# ---> 11 model = HQQModelForCausalLM.from_pretrained(
#      12     model_id,
#      13     device_map="auto"  # تخصيص تلقائي للجهاز (CUDA)
#
# /usr/local/lib/python3.11/dist-packages/hqq/engine/hf.py in from_pretrained(cls, *args, **kwargs)
#      64     def from_pretrained(cls, *args, **kwargs):
#      65         cls._validate_params(kwargs)
# ---> 66         model = super(_Parent, cls).from_pretrained(*args, **kwargs)
#      67         cls._make_quantizable(model, quantized=False)
#      68         return model
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
# ...

# %%
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
import torch

# تأكد من استخدام GPU
assert torch.cuda.is_available(), "⚠️ تأكد من تشغيل GPU في كولاب!"

# اسم النموذج
model_id = "mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq"

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحميل النموذج باستخدام HQQ
model = HQQModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",  # تخصيص تلقائي لـ GPU
)

# تحويل النموذج إلى CUDA
model.to("cuda")

print("✅ تم تحميل النموذج بنجاح!")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-8a0e04d76a91> in <cell line: 0>()
#      12
#      13 # تحميل النموذج باستخدام HQQ
# ---> 14 model = HQQModelForCausalLM.from_pretrained(
#      15     model_id,
#      16     device_map="auto",  # تخصيص تلقائي لـ GPU
#
# /usr/local/lib/python3.11/dist-packages/hqq/engine/hf.py in from_pretrained(cls, *args, **kwargs)
#      64     def from_pretrained(cls, *args, **kwargs):
#      65         cls._validate_params(kwargs)
# ---> 66         model = super(_Parent, cls).from_pretrained(*args, **kwargs)
#      67         cls._make_quantizable(model, quantized=False)
#      68         return model
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
# ...

# %%
# !rm -rf ~/.cache/huggingface

# %%
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
import torch

# تأكد من تفعيل الـ GPU
assert torch.cuda.is_available(), "⚠️ تأكد من تشغيل GPU في كولاب!"
print(f"✅ GPU: {torch.cuda.get_device_name(0)}")

# اسم النموذج
model_id = "mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq"

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحميل النموذج من qmodel.pt
model = HQQModelForCausalLM.from_pretrained(
    model_id,
    filename="qmodel.pt",  # التأكد من تحميل الملف الصحيح
    device_map="auto"
)

# نقل النموذج إلى GPU
model.to("cuda")

print("✅ تم تحميل النموذج بنجاح!")
# Out:
# ✅ GPU: Tesla T4
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-603facd5037b> in <cell line: 0>()
#      13
#      14 # تحميل النموذج من qmodel.pt
# ---> 15 model = HQQModelForCausalLM.from_pretrained(
#      16     model_id,
#      17     filename="qmodel.pt",  # التأكد من تحميل الملف الصحيح
#
# /usr/local/lib/python3.11/dist-packages/hqq/engine/hf.py in from_pretrained(cls, *args, **kwargs)
#      64     def from_pretrained(cls, *args, **kwargs):
#      65         cls._validate_params(kwargs)
# ---> 66         model = super(_Parent, cls).from_pretrained(*args, **kwargs)
# ...

# %%
import torch
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
from hqq.core.quantize import BaseQuantizeConfig
from hqq.utils.patching import patch_linearlayers
from hqq.utils.generation_hf import HFGenerator

# تأكد من أن T4 متاح ويعمل
assert torch.cuda.is_available(), "⚠️ تأكد من تفعيل GPU في كولاب!"
device = torch.device("cuda")
print(f"✅ GPU: {torch.cuda.get_device_name(0)}")

# تحميل النموذج
model_id = "mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq"

# تحديد إعدادات التحميل
compute_dtype = torch.bfloat16  # استخدام BF16 بدلاً من FP16 لأن T4 يعمل به بكفاءة
adapter_path = "adapter_v0.1.lora"  # تأكد من أن هذا الملف موجود وإلا قم بإزالته

try:
    model = HQQModelForCausalLM.from_quantized(
        model_id,
        cache_dir=".",
        compute_dtype=compute_dtype,
        adapter=adapter_path  # يمكن إزالته إذا استمر الخطأ
    )
except Exception as e:
    print(f"⚠️ خطأ أثناء تحميل النموذج: {e}")
    model = None

if model:
    tokenizer = AutoTokenizer.from_pretrained(model_id)

    # تفعيل التكميم المناسب
    patch_linearlayers(
        model,
        patch_add_quant_config,
        BaseQuantizeConfig(nbits=2, group_size=64, quant_scale=False, quant_zero=False, axis=1)
    )

    model.eval()
    print("✅ تم تحميل النموذج بنجاح!")

    # استخدام طريقة تشغيل متوافقة مع T4
    gen = HFGenerator(model, tokenizer, max_new_tokens=500, do_sample=True, compile=None)

    # تجربة توليد نص
    text = "ما هو الذكاء الاصطناعي؟"
    output = gen.generate(text, print_tokens=True)
    print("📝 الإخراج:", output)
# Out:
# ...
# ✅ GPU: Tesla T4
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# ...

# %%
import torch
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
from hqq.core.quantize import BaseQuantizeConfig
from hqq.utils.patching import patch_linearlayers
#from hqq.core.patching import patch_add_quant_config  # ✅ إصلاح المشكلة
from hqq.utils.generation_hf import HFGenerator
from hqq.utils.patching import patch_add_quant_config
from hqq.utils.patching import patch_add_quant_config




# تأكد من تشغيل GPU
assert torch.cuda.is_available(), "⚠️ تأكد من تفعيل GPU في كولاب!"
device = torch.device("cuda")
print(f"✅ GPU: {torch.cuda.get_device_name(0)}")

# تحميل النموذج
model_id = "mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq"

# اختيار دقة الحساب المتوافقة مع T4
compute_dtype = torch.bfloat16  # BF16 أفضل لـ T4
adapter_path = "adapter_v0.1.lora"

try:
    model = HQQModelForCausalLM.from_quantized(
        model_id,
        cache_dir=".",
        compute_dtype=compute_dtype,
        adapter=adapter_path
    )
except Exception as e:
    print(f"⚠️ خطأ أثناء تحميل النموذج: {e}")
    model = None

if model:
    tokenizer = AutoTokenizer.from_pretrained(model_id)

    # ✅ إصلاح استدعاء `patch_add_quant_config`
    patch_linearlayers(
        model,
        patch_add_quant_config,  # ✅ تم إصلاح الخطأ
        BaseQuantizeConfig(nbits=2, group_size=64, quant_scale=False, quant_zero=False, axis=1)
    )

    model.eval()
    print("✅ تم تحميل النموذج بنجاح!")

    # تعطيل bitblas لأنه قد لا يعمل على T4
    # prepare_for_inference(model, backend="bitblas", allow_merge=False)
    prepare_for_inference(model)

    # تجربة توليد النص
    gen = HFGenerator(model, tokenizer, max_new_tokens=500, do_sample=True, compile=None)

    text = "ما هو الذكاء الاصطناعي؟"
    output = gen.generate(text, print_tokens=True)
    print("📝 الإخراج:", output)
# Out:
# ✅ GPU: Tesla T4
# ...
# 100%|██████████| 32/32 [00:00<00:00, 5132.22it/s]
# ✅ تم تحميل النموذج بنجاح!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3f42711eeb7c> in <cell line: 0>()
#      49     # تعطيل bitblas لأنه قد لا يعمل على T4
#      50     # prepare_for_inference(model, backend="bitblas", allow_merge=False)
# ---> 51     prepare_for_inference(model)
#      52
#      53     # تجربة توليد النص
#
# NameError: name 'prepare_for_inference' is not defined

# %%
# !pip install git+https://github.com/0hq/hqq
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#   Cloning https://github.com/0hq/hqq to /tmp/pip-req-build-ddmnh9mk
#   Running command git clone --filter=blob:none --quiet https://github.com/0hq/hqq /tmp/pip-req-build-ddmnh9mk
#   fatal: could not read Username for 'https://github.com': No such device or address
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/0hq/hqq /tmp/pip-req-build-ddmnh9mk did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# ...

# %%
import hqq
print(dir(hqq))
# Out:
# ['__author__', '__builtins__', '__cached__', '__credits__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'backends', 'core', 'engine', 'models', 'utils']

# %%
import hqq.utils
print(dir(hqq.utils))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'generation_hf', 'patching']

# %%
# !git clone https://github.com/mobiusml/hqq.git
# Out:
# Cloning into 'hqq'...
# remote: Enumerating objects: 1763, done.
# remote: Counting objects: 100% (530/530), done.
# remote: Compressing objects: 100% (252/252), done.
# remote: Total 1763 (delta 355), reused 287 (delta 278), pack-reused 1233 (from 2)
# Receiving objects: 100% (1763/1763), 488.49 KiB | 1.75 MiB/s, done.
# Resolving deltas: 100% (1120/1120), done.

# %%
# %cd hqq
# !pip install .
# Out:
# /content/hqq
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Processing /content/hqq
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for hqq: filename=hqq-0.2.3-py3-none-any.whl size=68485 sha256=c4f505e25ed894b162c3e5ec77809b467c36261cf684fa4bbed154f04b5aee9b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xs80_jj4/wheels/d4/14/8b/e86c6449e2f3fc376af788c414d636f43d937d2e9c178ff50c
# Successfully built hqq
# ...
#   Attempting uninstall: hqq
#     Found existing installation: hqq 0.2.3
#     Can't uninstall 'hqq'. No files were found to uninstall.
# ...

# %%
import transformers
from threading import Thread

def chat_processor(chat, max_new_tokens=100, do_sample=True):
    tokenizer.use_default_system_prompt = False
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda'),
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature= 0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.generate, kwargs=generate_params)
    t.start()

    print('------------------------------------------------------------')
    cleanup()
    print(chat); print();
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

################################################################################################
#Generation
outputs = chat_processor("How do I build a car?", max_new_tokens=100, do_sample=False)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6844cddad4a1> in <cell line: 0>()
#      33 ################################################################################################
#      34 #Generation
# ---> 35 outputs = chat_processor("How do I build a car?", max_new_tokens=100, do_sample=False)
#
# <ipython-input-1-6844cddad4a1> in chat_processor(chat, max_new_tokens, do_sample)
#       3
#       4 def chat_processor(chat, max_new_tokens=100, do_sample=True):
# ----> 5     tokenizer.use_default_system_prompt = False
# ...

# %%
from hqq.engine.hf import HQQModelForCausalLM
import transformers
from threading import Thread

# %%
model_path = "/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq"
model = HQQModelForCausalLM.from_pretrained(model_path, device_map="auto")
tokenizer = transformers.AutoTokenizer.from_pretrained(model_path)

# %%
generate_params = dict(
        input_ids=tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda').input_ids,
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature=0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.model.generate, kwargs=generate_params)  # Use model.model.generate

# %%
from hqq.engine.hf import HQQModelForCausalLM
import transformers
from threading import Thread

def chat_processor(chat, max_new_tokens=100, do_sample=True):
    tokenizer.use_default_system_prompt = False
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        input_ids=tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda').input_ids,
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature=0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.model.generate, kwargs=generate_params)  # Use model.model.generate
    t.start()

    print('------------------------------------------------------------')
    # cleanup()  # Remove or adjust cleanup if needed
    print(chat); print();
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

# Load the model and tokenizer
model_path = "/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq"
model = HQQModelForCausalLM.from_pretrained(model_path, device_map="auto")
tokenizer = transformers.AutoTokenizer.from_pretrained(model_path)

# Generation
outputs = chat_processor("How do I build a car?", max_new_tokens=100, do_sample=False)

# %%
model_id = 'mobiuslabsgmbh/Llama-3-8b-instruct_2bitgs64_hqq'
model     = HQQModelForCausalLM.from_quantized(model_id, cache_dir='.', compute_dtype=torch.float16, adapter='adapter_v0.1.lora')
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %% [markdown]
# aشغغغغغغغغغغغغغغغغغغغغغغغغغغغغغغغغغغغ

# %%
from hqq.engine.hf import HQQModelForCausalLM
import transformers
from threading import Thread
import torch
from transformers import AutoTokenizer
def chat_processor(chat, max_new_tokens=100, do_sample=True):
    tokenizer.use_default_system_prompt = False
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        input_ids=tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda').input_ids,
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature=0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.model.generate, kwargs=generate_params)  # Use model.model.generate
    t.start()

    print('------------------------------------------------------------')
    # cleanup()  # Remove or adjust cleanup if needed
    print(chat); print();
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

# Load the model and tokenizer
model_path = "/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq/snapshots/e3c28105c5acd6ecf91642b345388b11a9bcd91b"
#model = HQQModelForCausalLM.from_pretrained(model_path, device_map="auto")
#tokenizer = transformers.AutoTokenizer.from_pretrained(model_path)
model     = HQQModelForCausalLM.from_quantized(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)
# Generation
outputs = chat_processor("How do I build a car?", max_new_tokens=100, do_sample=False)

# %%
import transformers
from threading import Thread

# ... (rest of your code)

# Load the model and tokenizer using AutoModelForCausalLM
model_path = "/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq"
model = transformers.AutoModelForCausalLM.from_pretrained(model_path, device_map="auto")  # Use AutoModelForCausalLM
tokenizer = transformers.AutoTokenizer.from_pretrained(model_path)

# ... (rest of your code)

# Use model.generate directly instead of model.model.generate
t = Thread(target=model.generate, kwargs=generate_params)  # Use model.generate
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-4b0bab069c5f> in <cell line: 0>()
#       6 # Load the model and tokenizer using AutoModelForCausalLM
#       7 model_path = "/content/models--mobiuslabsgmbh--Llama-3-8b-instruct_2bitgs64_hqq"
# ----> 8 model = transformers.AutoModelForCausalLM.from_pretrained(model_path, device_map="auto")  # Use AutoModelForCausalLM
#       9 tokenizer = transformers.AutoTokenizer.from_pretrained(model_path)
#      10
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566             )
# --> 567         raise ValueError(
# ...
