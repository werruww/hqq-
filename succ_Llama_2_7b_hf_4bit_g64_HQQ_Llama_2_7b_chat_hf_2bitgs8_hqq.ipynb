# %%
# !pip install hqq==0.1.8
# !pip install transformers==4.46.0
# Out:
# Collecting hqq==0.1.8
#   Downloading hqq-0.1.8.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (1.26.4)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (4.67.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (0.8.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (1.3.0)
# Requirement already satisfied: transformers>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (4.48.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (0.28.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (2.5.0)
# Collecting bitblas (from hqq==0.1.8)
#   Downloading bitblas-0.1.0-py3-none-manylinux1_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (3.17.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (0.5.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->hqq==0.1.8) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->hqq==0.1.8) (4.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->hqq==0.1.8) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->hqq==0.1.8) (2.5.1+cu124)
# Requirement already satisfied: cffi in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (1.17.1)
# Collecting cpplint (from bitblas->hqq==0.1.8)
#   Downloading cpplint-2.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (3.0.11)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (4.4.2)
# Requirement already satisfied: docutils in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (0.21.2)
# Collecting dtlib (from bitblas->hqq==0.1.8)
#   Downloading dtlib-0.0.0.dev2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pytest>=6.2.4 in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (8.3.4)
# Collecting pytest-xdist>=2.2.1 (from bitblas->hqq==0.1.8)
#   Downloading pytest_xdist-3.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (25.1.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (3.1.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (0.4.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (1.13.1)
# Requirement already satisfied: tornado in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (6.4.2)
# Collecting thefuzz (from bitblas->hqq==0.1.8)
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (0.9.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest>=6.2.4->bitblas->hqq==0.1.8) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=6.2.4->bitblas->hqq==0.1.8) (1.5.0)
# Collecting execnet>=2.1 (from pytest-xdist>=2.2.1->bitblas->hqq==0.1.8)
#   Downloading execnet-2.1.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate->hqq==0.1.8) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi->bitblas->hqq==0.1.8) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (2025.1.31)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz->bitblas->hqq==0.1.8)
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate->hqq==0.1.8) (3.0.2)
# Downloading bitblas-0.1.0-py3-none-manylinux1_x86_64.whl (88.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 MB 6.5 MB/s eta 0:00:00
# Downloading pytest_xdist-3.6.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 45.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.4 MB/s eta 0:00:00
# Downloading cpplint-2.0.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.0 MB/s eta 0:00:00
# Downloading dtlib-0.0.0.dev2-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 5.1 MB/s eta 0:00:00
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Downloading execnet-2.1.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 3.8 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.4 MB/s eta 0:00:00
# Building wheels for collected packages: hqq
#   Building wheel for hqq (setup.py) ... done
#   Created wheel for hqq: filename=hqq-0.1.8-py3-none-any.whl size=61842 sha256=f8f0f1a7cec7e8995a13feb94a95b963d4557906dc3497a2d968a4ef39dc6aba
#   Stored in directory: /root/.cache/pip/wheels/48/c9/d7/e9a4d0e9ff9ec96c2b629713b55e0221fee3f1ca41071b0a5e
# Successfully built hqq
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Installing collected packages: cpplint, rapidfuzz, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, execnet, dtlib, thefuzz, pytest-xdist, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitblas, hqq
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitblas-0.1.0 cpplint-2.0.0 dtlib-0.0.0.dev2 execnet-2.1.1 hqq-0.1.8 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytest-xdist-3.6.1 rapidfuzz-3.12.1 thefuzz-0.22.1
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting transformers==4.46.0
#   Downloading transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (0.5.2)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.0)
#   Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (2025.1.31)
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.46.0 at https://files.pythonhosted.org/packages/db/88/1ef8a624a33d7fe460a686b9e0194a7916320fc0d67d4e38e570beeac039/transformers-4.46.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.8.0))
# Reason for being yanked: This version unfortunately does not work with 3.8 but we did not drop the support yet
# Downloading transformers-4.46.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 24.6 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 96.2 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.2
#     Uninstalling transformers-4.48.2:
#       Successfully uninstalled transformers-4.48.2
# Successfully installed tokenizers-0.20.3 transformers-4.46.0

# %%
import torch, os

cache_path    = '.'
compute_dtype = torch.float16
device        = 'cuda:0'
###################################################################################################
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig

model_id      = "meta-llama/Llama-2-7b-hf"

#Basic
#Linear layers will use the same quantization config
quant_config  = HqqConfig(nbits=8, group_size=64, quant_zero=False, quant_scale=False, axis=0) #axis=0 is used by default

#Each type of linear layer (referred to as linear tag) will use different quantization parameters
# q4_config = {'nbits':4, 'group_size':64, 'quant_zero':False, 'quant_scale':False}
# q3_config = {'nbits':3, 'group_size':32, 'quant_zero':False, 'quant_scale':False}
# quant_config  = HqqConfig(dynamic_config={
#   'self_attn.q_proj':q4_config,
#   'self_attn.k_proj':q4_config,
#   'self_attn.v_proj':q4_config,
#   'self_attn.o_proj':q4_config,

#   'mlp.gate_proj':q3_config,
#   'mlp.up_proj'  :q3_config,
#   'mlp.down_proj':q3_config,
#   })

#####################################################################################################

model     = AutoModelForCausalLM.from_pretrained(model_id,
                                                cache_dir=cache_path,
                                                torch_dtype=compute_dtype,
                                                device_map="auto", #device
                                                low_cpu_mem_usage=True,
                                                quantization_config=quant_config
                                                )


#Set backend
from hqq.core.quantize import *
from hqq.core.utils import cleanup
HQQLinear.set_backend(HQQBackend.ATEN)

#Forward
with torch.no_grad():
	out = model(torch.zeros([1, 1024], device=device, dtype=torch.int32)).logits

print(out)
del out
cleanup()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-6ad749be15ac> in <cell line: 0>()
#      11 #Basic
#      12 #Linear layers will use the same quantization config
# ---> 13 quant_config  = HqqConfig(nbits=8, group_size=64, quant_zero=False, quant_scale=False, axis=0) #axis=0 is used by default
#      14
#      15 #Each type of linear layer (referred to as linear tag) will use different quantization parameters
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/quantization_config.py in __init__(self, nbits, group_size, view_as_float, axis, dynamic_config, skip_modules, **kwargs)
#     242                 self.quant_config[key] = HQQBaseQuantizeConfig(**dynamic_config[key])
#     243         else:
# --> 244             self.quant_config = HQQBaseQuantizeConfig(
#     245                 **{
#     246                     "nbits": nbits,
#
# UnboundLocalError: cannot access local variable 'HQQBaseQuantizeConfig' where it is not associated with a value

# %%
import torch, os

cache_path    = '.'
compute_dtype = torch.float16
device        = 'cuda:0'
###################################################################################################
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig
# Import HQQBaseQuantizeConfig to resolve the error
from hqq.core.quantize import HQQBaseQuantizeConfig

model_id      = "meta-llama/Llama-2-7b-hf"

#Basic
#Linear layers will use the same quantization config
quant_config  = HqqConfig(nbits=8, group_size=64, quant_zero=False, quant_scale=False, axis=0) #axis=0 is used by default

# ... (rest of your code)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig
# Import HQQBaseQuantizeConfig to resolve the error
from hqq.core.quantize import HQQBaseQuantizeConfig

import torch, os

cache_path    = '.'
compute_dtype = torch.float16
device        = 'cuda:0'
###################################################################################################
from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig

model_id      = "meta-llama/Llama-2-7b-hf"

#Basic
#Linear layers will use the same quantization config
quant_config  = HqqConfig(nbits=8, group_size=64, quant_zero=False, quant_scale=False, axis=0)

#Each type of linear layer (referred to as linear tag) will use different quantization parameters
# q4_config = {'nbits':4, 'group_size':64, 'quant_zero':False, 'quant_scale':False}
# q3_config = {'nbits':3, 'group_size':32, 'quant_zero':False, 'quant_scale':False}
# quant_config  = HqqConfig(dynamic_config={
#   'self_attn.q_proj':q4_config,
#   'self_attn.k_proj':q4_config,
#   'self_attn.v_proj':q4_config,
#   'self_attn.o_proj':q4_config,

#   'mlp.gate_proj':q3_config,
#   'mlp.up_proj'  :q3_config,
#   'mlp.down_proj':q3_config,
#   })

#####################################################################################################

model     = AutoModelForCausalLM.from_pretrained(model_id,
                                                cache_dir=cache_path,
                                                torch_dtype=compute_dtype,
                                                device_map="auto", #device
                                                low_cpu_mem_usage=True,
                                                quantization_config=quant_config
                                                )


#Set backend
from hqq.core.quantize import *
from hqq.core.utils import cleanup
HQQLinear.set_backend(HQQBackend.ATEN)

#Forward
with torch.no_grad():
	out = model(torch.zeros([1, 1024], device=device, dtype=torch.int32)).logits

print(out)
del out
cleanup()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-a018037b7953> in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer, HqqConfig
#       2 # Import HQQBaseQuantizeConfig to resolve the error
# ----> 3 from hqq.core.quantize import HQQBaseQuantizeConfig
#       4
#       5 import torch, os
#
# ImportError: cannot import name 'HQQBaseQuantizeConfig' from 'hqq.core.quantize' (/usr/local/lib/python3.11/dist-packages/hqq/core/quantize.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model     = HQQModelForCausalLM.from_quantized(model_id)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/868 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/788 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/868 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/656 [00:00<?, ?B/s]
# qmodel.pt:   0%|          | 0.00/4.07G [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# 100%|██████████| 32/32 [00:00<00:00, 837.58it/s]
# 100%|██████████| 32/32 [00:00<00:00, 1168.47it/s]

# %%
from hqq.core.quantize import *
HQQLinear.set_backend(HQQBackend.ATEN_BACKPROP)
import transformers

def chat_processor(chat, max_new_tokens=1, do_sample=True):
    tokenizer.use_default_system_prompt = False
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda'),
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature= 0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.generate, kwargs=generate_params)
    t.start()
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

################################################################################################
#Generation
outputs = chat_processor("How do I build a car?", max_new_tokens=1, do_sample=False)
# Out:
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-dd7a58baa13c> in <cell line: 0>()
#      30 ################################################################################################
#      31 #Generation
# ---> 32 outputs = chat_processor("How do I build a car?", max_new_tokens=1, do_sample=False)
#
# <ipython-input-6-dd7a58baa13c> in chat_processor(chat, max_new_tokens, do_sample)
#      19     )
#      20
# ---> 21     t = Thread(target=model.generate, kwargs=generate_params)
#      22     t.start()
#      23     outputs = []
#
# NameError: name 'Thread' is not defined

# %%
import transformers
from threading import Thread

model_id = 'mobiuslabsgmbh/Mixtral-8x7B-Instruct-v0.1-hf-attn-4bit-moe-2bit-metaoffload-HQQ'
#Load the model
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model     = HQQModelForCausalLM.from_quantized(model_id)

#Optional: set backend/compile
#You will need to install CUDA kernels apriori
# git clone https://github.com/mobiusml/hqq/
# cd hqq/kernels && python setup_cuda.py install
from hqq.core.quantize import *
HQQLinear.set_backend(HQQBackend.ATEN_BACKPROP)


def chat_processor(chat, max_new_tokens=100, do_sample=True):
    tokenizer.use_default_system_prompt = False
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda'),
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature= 0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.generate, kwargs=generate_params)
    t.start()
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

################################################################################################
#Generation
outputs = chat_processor("How do I build a car?", max_new_tokens=1000, do_sample=False)

# %%
from hqq.core.quantize import *
HQQLinear.set_backend(HQQBackend.ATEN_BACKPROP)
# Import the transformers module
import transformers

def chat_processor(chat, max_new_tokens=1, do_sample=True):
    tokenizer.use_default_system_prompt = False
    # Now you can use transformers.TextIteratorStreamer
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda'),
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature= 0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.generate, kwargs=generate_params)
    t.start()
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

################################################################################################
#Generation
outputs = chat_processor("How do I build a car?", max_new_tokens=1, do_sample=False)
# Out:
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-13b6dcc6b7f2> in <cell line: 0>()
#      32 ################################################################################################
#      33 #Generation
# ---> 34 outputs = chat_processor("How do I build a car?", max_new_tokens=1, do_sample=False)
#
# <ipython-input-7-13b6dcc6b7f2> in chat_processor(chat, max_new_tokens, do_sample)
#      21     )
#      22
# ---> 23     t = Thread(target=model.generate, kwargs=generate_params)
#      24     t.start()
#      25     outputs = []
#
# NameError: name 'Thread' is not defined

# %%
from hqq.core.quantize import *
HQQLinear.set_backend(HQQBackend.ATEN_BACKPROP)
# Import the transformers module
import transformers
# Import the Thread class from the threading module
from threading import Thread

def chat_processor(chat, max_new_tokens=1, do_sample=True):
    tokenizer.use_default_system_prompt = False
    # Now you can use transformers.TextIteratorStreamer
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda'),
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature= 0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.generate, kwargs=generate_params)
    t.start()
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

################################################################################################
#Generation
outputs = chat_processor("How do I build a car?", max_new_tokens=1, do_sample=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:595: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Exception in thread Thread-14 (generate):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py", line 2215, in generate
#     result = self._sample(
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py", line 3206, in _sample
#     outputs = self(**model_inputs, return_dict=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 1190, in forward
#     outputs = self.model(
#               ^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 921, in forward
#     position_embeddings = self.rotary_emb(hidden_states, position_ids)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 158, in forward
#     freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(1, 2)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_bmm)
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# <ipython-input-8-3fd393d9fac3> in <cell line: 0>()
#      34 ################################################################################################
#      35 #Generation
# ---> 36 outputs = chat_processor("How do I build a car?", max_new_tokens=1, do_sample=False)
#
# <ipython-input-8-3fd393d9fac3> in chat_processor(chat, max_new_tokens, do_sample)
#      26     t.start()
#      27     outputs = []
# ---> 28     for text in streamer:
#      29         outputs.append(text)
#      30         print(text, end="", flush=True)
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/streamers.py in __next__(self)
#     221
#     222     def __next__(self):
# --> 223         value = self.text_queue.get(timeout=self.timeout)
#     224         if value == self.stop_signal:
#     225             raise StopIteration()
#
# /usr/lib/python3.11/queue.py in get(self, block, timeout)
#     177                     remaining = endtime - time()
#     178                     if remaining <= 0.0:
# --> 179                         raise Empty
#     180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#
# Empty:

# %%
# !pip show torch
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Name: torch
# Version: 2.5.1+cu124
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, bitblas, fastai, peft, sentence-transformers, timm, torchaudio, torchvision

# %%
from hqq.core.quantize import *
HQQLinear.set_backend(HQQBackend.ATEN_BACKPROP)
# Import the transformers module
import transformers
# Import the Thread class from the threading module
from threading import Thread

def chat_processor(chat, max_new_tokens=100, do_sample=True): # Increased max_new_tokens
    tokenizer.use_default_system_prompt = False
    # Now you can use transformers.TextIteratorStreamer
    # Increased timeout to 60 seconds
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=60.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to('cuda'),
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        top_p=0.90,
        top_k=50,
        temperature= 0.6,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.generate, kwargs=generate_params)
    t.start()
    outputs = []
    for text in streamer:
        outputs.append(text)
        print(text, end="", flush=True)

    return outputs

################################################################################################
#Generation
# Increased max_new_tokens to 100
outputs = chat_processor("How do I build a car?", max_new_tokens=100, do_sample=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:595: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Exception in thread Thread-15 (generate):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py", line 2215, in generate
#     result = self._sample(
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py", line 3206, in _sample
#     outputs = self(**model_inputs, return_dict=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 1190, in forward
#     outputs = self.model(
#               ^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 921, in forward
#     position_embeddings = self.rotary_emb(hidden_states, position_ids)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 158, in forward
#     freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(1, 2)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_bmm)
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4a6477a8ed73> in <cell line: 0>()
#      36 #Generation
#      37 # Increased max_new_tokens to 100
# ---> 38 outputs = chat_processor("How do I build a car?", max_new_tokens=100, do_sample=False)
#
# <ipython-input-10-4a6477a8ed73> in chat_processor(chat, max_new_tokens, do_sample)
#      27     t.start()
#      28     outputs = []
# ---> 29     for text in streamer:
#      30         outputs.append(text)
#      31         print(text, end="", flush=True)
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/streamers.py in __next__(self)
#     221
#     222     def __next__(self):
# --> 223         value = self.text_queue.get(timeout=self.timeout)
#     224         if value == self.stop_signal:
#     225             raise StopIteration()
#
# /usr/lib/python3.11/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     329             else:
#     330                 if timeout > 0:
# --> 331                     gotit = waiter.acquire(True, timeout)
#     332                 else:
#     333                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model     = HQQModelForCausalLM.from_quantized(model_id)

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = HQQModelForCausalLM.from_quantized(model_id)

prompt = "Capital of India"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
print(tokenizer.decode(generate_ids))
# Out:
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# 100%|██████████| 32/32 [00:00<00:00, 2390.73it/s]
# 100%|██████████| 32/32 [00:00<00:00, 288.52it/s]
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# Warning: the ATEN/CUDA backend only supports axis=0 and GPU runtime.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-aad5cbeff47f> in <cell line: 0>()
#       7 prompt = "Capital of India"
#       8 inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
# ----> 9 generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
#      10 print(tokenizer.decode(generate_ids))
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2213
#    2214             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2215             result = self._sample(
#    2216                 input_ids,
#    2217                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3204
#    3205             # forward pass to get next token
# -> 3206             outputs = self(**model_inputs, return_dict=True)
#    3207
#    3208             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#    1188
#    1189         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1190         outputs = self.model(
#    1191             input_ids=input_ids,
#    1192             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     919
#     920         # create position embeddings to be shared across the decoder layers
# --> 921         position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     922
#     923         # decoder layers
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x, position_ids)
#     156         device_type = device_type if isinstance(device_type, str) and device_type != "mps" else "cpu"
#     157         with torch.autocast(device_type=device_type, enabled=False):
# --> 158             freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(1, 2)
#     159             emb = torch.cat((freqs, freqs), dim=-1)
#     160             cos = emb.cos()
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_bmm)

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model     = HQQModelForCausalLM.from_quantized(model_id)

model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = HQQModelForCausalLM.from_quantized(model_id)

prompt = "Capital of India"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
print(tokenizer.decode(generate_ids))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# 100%|██████████| 32/32 [00:00<00:00, 733.35it/s]
# 100%|██████████| 32/32 [00:00<00:00, 655.97it/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# 100%|██████████| 32/32 [00:00<00:00, 438.33it/s]
# 100%|██████████| 32/32 [00:00<00:00, 902.81it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-2927de4311da> in <cell line: 0>()
#      13 prompt = "Capital of India"
#      14 inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
# ---> 15 generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
#      16 print(tokenizer.decode(generate_ids))
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2213
#    2214             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2215             result = self._sample(
#    2216                 input_ids,
#    2217                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3204
#    3205             # forward pass to get next token
# -> 3206             outputs = self(**model_inputs, return_dict=True)
#    3207
#    3208             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#    1188
#    1189         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1190         outputs = self.model(
#    1191             input_ids=input_ids,
#    1192             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     919
#     920         # create position embeddings to be shared across the decoder layers
# --> 921         position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     922
#     923         # decoder layers
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x, position_ids)
#     156         device_type = device_type if isinstance(device_type, str) and device_type != "mps" else "cpu"
#     157         with torch.autocast(device_type=device_type, enabled=False):
# --> 158             freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(1, 2)
#     159             emb = torch.cat((freqs, freqs), dim=-1)
#     160             cos = emb.cos()
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_bmm)

# %%
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = HQQModelForCausalLM.from_quantized(model_id)

prompt = "Capital of India"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
print(tokenizer.decode(generate_ids))

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = HQQModelForCausalLM.from_quantized(model_id)

# Move the model to the GPU before generating
model.to('cuda')

prompt = "Capital of India"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
print(tokenizer.decode(generate_ids))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# 100%|██████████| 32/32 [00:00<00:00, 963.70it/s]
# 100%|██████████| 32/32 [00:00<00:00, 1121.82it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-920c317a43e6> in <cell line: 0>()
#      10 prompt = "Capital of India"
#      11 inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
# ---> 12 generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
#      13 print(tokenizer.decode(generate_ids))
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2213
#    2214             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2215             result = self._sample(
#    2216                 input_ids,
#    2217                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3204
#    3205             # forward pass to get next token
# -> 3206             outputs = self(**model_inputs, return_dict=True)
#    3207
#    3208             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#    1188
#    1189         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1190         outputs = self.model(
#    1191             input_ids=input_ids,
#    1192             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     919
#     920         # create position embeddings to be shared across the decoder layers
# --> 921         position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     922
#     923         # decoder layers
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x, position_ids)
#     156         device_type = device_type if isinstance(device_type, str) and device_type != "mps" else "cpu"
#     157         with torch.autocast(device_type=device_type, enabled=False):
# --> 158             freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(1, 2)
#     159             emb = torch.cat((freqs, freqs), dim=-1)
#     160             cos = emb.cos()
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_bmm)

# %% [markdown]
# ### شغال

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = HQQModelForCausalLM.from_quantized(model_id)

# Move the model and its rotary embedding to the GPU
model.to('cuda')
model.model.rotary_emb.to('cuda')  # Explicitly move rotary_emb to GPU

prompt = "Capital of India"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
print(tokenizer.decode(generate_ids))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# 100%|██████████| 32/32 [00:00<00:00, 577.45it/s]
# 100%|██████████| 32/32 [00:00<00:00, 1108.60it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# <s> Capital of India, Delhi is a city of contrasts. surely, the city is a blend of the old and the new. The

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-hf-4bit_g64-HQQ'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = HQQModelForCausalLM.from_quantized(model_id)

# Move the model and its rotary embedding to the GPU
model.to('cuda')
model.model.rotary_emb.to('cuda')  # Explicitly move rotary_emb to GPU

prompt = "Capital of India"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
print(tokenizer.decode(generate_ids))

# %%
prompt = "what is ai?"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=300)[0]
print(tokenizer.decode(generate_ids))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# <s> what is ai?
#  nobody knows.
#
# ### 1. 概念
#
# - 人工智能
# - 机器人
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人工智能
# - 人

# %%
prompt = "Who is Einstein?"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=300)[0]
print(tokenizer.decode(generate_ids))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# <s> Who is Einstein?
#  surely you know Einstein, the famous scientist who discovered the theory of relativity.
# Einstein is a scientist who discovered the theory of relativity.
# Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scientist who discovered the theory of relativity. Einstein is a scient

# %%
prompt = "Who is Einstein?"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=300, do_sample=True)[0]  # Add do_sample=False here
print(tokenizer.decode(generate_ids))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# <s> Who is Einstein?
# ☉ ☿ Lunar eclipse ♃♑ Uranus-Ceres conjunction ☉ ☿
# Birthday: 1879, March 14th
# Birthplace: Ulm, Germany
# Father : Hermann Einstein (1847–1902), engineer
# Mother : Pauline Koch (1858–1920), homemaker
# The most famous of all physicists, he was a revolutionary thinker who has profoundly influenced our understanding of nature, of ourselves, and of the world in which we live. He devised the general theory of relativity, one of the two pillars of modern physics (alongside quantum theory). He is widely recognized as one of the greatest and most influential scientists of all times. Einstein was a theoretical physicist and one of the key pioneers of our current understanding of both general relativity and quantum mechanics. He received the 1921 Nobel Prize for Physics "for his services to theoretical physics, and especially for his discovery of the law of the photoelectric effect". As a child, Einstein was considered slow in school—not because he was slow-witted, but because his own individual style of learning meant that he did not make the same progress at school as did his friends. By the age of

# %%
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer

#Load the model
model_id = 'mobiuslabsgmbh/Llama-2-7b-chat-hf_2bitgs8_hqq'
model     = HQQModelForCausalLM.from_quantized(model_id, adapter='adapter_v0.1.lora')
tokenizer = AutoTokenizer.from_pretrained(model_id)

#Setup Inference Mode
tokenizer.add_bos_token = False
tokenizer.add_eos_token = False
if not tokenizer.pad_token: tokenizer.add_special_tokens({'pad_token': '[PAD]'})
model.config.use_cache  = True
model.eval();

# Optional: torch compile for faster inference
# model = torch.compile(model)

#Streaming Inference
import torch, transformers
from threading import Thread

def chat_processor(chat, max_new_tokens=100, do_sample=True, device='cuda'):
    tokenizer.use_default_system_prompt = False
    streamer = transformers.TextIteratorStreamer(tokenizer, timeout=10.0, skip_prompt=True, skip_special_tokens=True)

    generate_params = dict(
        tokenizer("<s> [INST] " + chat + " [/INST] ", return_tensors="pt").to(device),
        streamer=streamer,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        pad_token_id=tokenizer.pad_token_id,
        top_p=0.90 if do_sample else None,
        top_k=50 if do_sample else None,
        temperature= 0.6 if do_sample else None,
        num_beams=1,
        repetition_penalty=1.2,
    )

    t = Thread(target=model.generate, kwargs=generate_params)
    t.start()

    print("User: ", chat);
    print("Assistant: ");
    outputs = ""
    for text in streamer:
        outputs += text
        print(text, end="", flush=True)

    torch.cuda.empty_cache()

    return outputs

# %%
model_id = 'mobiuslabsgmbh/Llama-2-7b-chat-hf_2bitgs8_hqq'

from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = HQQModelForCausalLM.from_quantized(model_id)

# Move the model and its rotary embedding to the GPU
model.to('cuda')
model.model.rotary_emb.to('cuda')  # Explicitly move rotary_emb to GPU

prompt = "Capital of India"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=30)[0]
print(tokenizer.decode(generate_ids))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.94k [00:00<?, ?B/s]
# qmodel.pt:   0%|          | 0.00/3.81G [00:00<?, ?B/s]
# adapter_v0.1.lora:   0%|          | 0.00/93.3M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# 100%|██████████| 32/32 [00:00<00:00, 903.22it/s]
# 100%|██████████| 32/32 [00:03<00:00,  8.76it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# <s> Capital of India, New Delhi, India
#
# The President of India,
#
# Sub: Request for Pardon of Death Sentence

# %%
prompt = "Who is Napoleon Bonaparte?"
inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
generate_ids = model.generate(inputs.input_ids, max_length=300, do_sample=True)[0]
print(tokenizer.decode(generate_ids))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# <s> Who is Napoleon Bonaparte?
# Napoleon Bonaparte was a French military and political leader who is best known for hisrole in the French Revolution and the Napoleonic Wars. He was born on August 15, 1769 in Ajaccio, Corsica and died on March 5, 1821 in Paris, France.
#
# Napoleon was a brilliant young man who distinguished himself in the French militaryand was eventually appointed to lead the French army in the Italian Campaign. He later led the French army to victory in the Battle of Lodi in 1796, and was able to conquer much of northern Italy, including the rich and powerful kingdom of Lombardy.
#
# Napoleon returned to Paris in 1797 and launched a coup against the government of the National Convention, which was dominated by moderate factions, including the Girondists and the Montagnards. He was successful in his coup and was elected First Consul of France, leading the country to victory in the War of the First Coaltionagainst Austria and other European powers.
#
# Napoleon's rise to power was marked by a series of military victories, including the Battle of Castelfranco in 1796, the Battle of Lodi in 1796, and the Battle of Ars in 179
